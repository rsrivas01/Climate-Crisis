# %%
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from splinter import Browser
from bs4 import BeautifulSoup as bs
import re
import time

# %% [markdown]
# # Use splinter & beautifulsoup to get the download path with gz file names

# %%
# for Windows
#executable_path = {'executable_path': 'C:\chromedriver\chromedriver'}

# for Mac
executable_path = {'executable_path': '/Users/ronaldrivas/chromedriver/chromedriver'}

browser = Browser('chrome', **executable_path)

# %%
url = 'https://www1.ncdc.noaa.gov/pub/data/swdi/stormevents/csvfiles/'
browser.visit(url)
time.sleep(2)
browser.is_element_present_by_text("legacy", wait_time=1)

html = browser.html
soup = bs(html, 'html.parser')

soup
# Out:
# <html><head>
# <title>Index of /pub/data/swdi/stormevents/csvfiles</title>
# </head>
# <body>
# <h1>Index of /pub/data/swdi/stormevents/csvfiles</h1>
# <table>
# <tbody><tr><th><a href="?C=N;O=D">Name</a></th><th><a href="?C=M;O=A">Last modified</a></th><th><a href="?C=S;O=A">Size</a></th><th><a href="?C=D;O=A">Description</a></th></tr>
# <tr><th colspan="4"><hr/></th></tr>
# <tr><td><a href="/pub/data/swdi/stormevents/">Parent Directory</a></td><td> </td><td align="right">  - </td><td> </td></tr>
# <tr><td><a href="Storm-Data-Bulk-csv-Format.pdf">Storm-Data-Bulk-csv-Format.pdf</a></td><td align="right">2020-07-17 13:10  </td><td align="right">161K</td><td> </td></tr>
# <tr><td><a href="Storm-Data-Export-Format.pdf">Storm-Data-Export-Format.pdf</a></td><td align="right">2020-07-17 09:17  </td><td align="right">163K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1950_c20170120.csv.gz">StormEvents_details-ftp_v1.0_d1950_c20170120.csv.gz</a></td><td align="right">2017-01-20 11:01  </td><td align="right"> 10K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1951_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1951_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 12K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1952_c20170619.csv.gz">StormEvents_details-ftp_v1.0_d1952_c20170619.csv.gz</a></td><td align="right">2017-06-19 09:20  </td><td align="right"> 12K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1953_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1953_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 21K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1954_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1954_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 26K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1955_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1955_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 52K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1956_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1956_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right"> 62K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1957_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1957_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 80K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1958_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1958_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 69K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1959_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1959_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 66K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1960_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1960_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 70K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1961_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1961_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 81K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1962_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1962_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 83K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1963_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1963_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 70K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1964_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1964_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 84K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1965_c20190920.csv.gz">StormEvents_details-ftp_v1.0_d1965_c20190920.csv.gz</a></td><td align="right">2019-09-20 12:30  </td><td align="right">102K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1966_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1966_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 81K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1967_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1967_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right"> 95K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1968_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1968_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">112K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1969_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1969_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right">100K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1970_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1970_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">112K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1971_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1971_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">123K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1972_c20181029.csv.gz">StormEvents_details-ftp_v1.0_d1972_c20181029.csv.gz</a></td><td align="right">2018-10-29 14:04  </td><td align="right"> 80K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1973_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1973_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">157K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1974_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1974_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">182K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1975_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1975_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">172K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1976_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1976_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">133K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1977_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1977_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">137K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1978_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1978_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">133K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1979_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1979_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">151K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1980_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1980_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right">211K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1981_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1981_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right">159K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1982_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1982_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">240K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1983_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1983_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">270K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1984_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1984_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right">248K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1985_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1985_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">263K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1986_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1986_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">291K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1987_c20160223.csv.gz">StormEvents_details-ftp_v1.0_d1987_c20160223.csv.gz</a></td><td align="right">2016-02-24 10:07  </td><td align="right">249K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1988_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1988_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right">250K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1989_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1989_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right">348K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1990_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d1990_c20170717.csv.gz</a></td><td align="right">2017-07-17 12:38  </td><td align="right">377K</td><td> </td></tr>
# <tr><td><a href="StormEvents_details-ftp_v1.0_d1991_c20170717.csv.gz">StormEvents_details-ftp_v1.0_d
c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d1999_c20200518.csv.gz
# StormEvents_details-ftp_v1.0_d2000_c20200707.csv.gz
# StormEvents_details-ftp_v1.0_d2001_c20200518.csv.gz
# StormEvents_details-ftp_v1.0_d2002_c20200518.csv.gz
# StormEvents_details-ftp_v1.0_d2003_c20200518.csv.gz
# StormEvents_details-ftp_v1.0_d2004_c20200518.csv.gz
# StormEvents_details-ftp_v1.0_d2005_c20200518.csv.gz
# StormEvents_details-ftp_v1.0_d2006_c20200518.csv.gz
# StormEvents_details-ftp_v1.0_d2007_c20170717.csv.gz
# StormEvents_details-ftp_v1.0_d2008_c20180718.csv.gz
# StormEvents_details-ftp_v1.0_d2009_c20180718.csv.gz
# StormEvents_details-ftp_v1.0_d2010_c20200922.csv.gz
# StormEvents_details-ftp_v1.0_d2011_c20180718.csv.gz
# StormEvents_details-ftp_v1.0_d2012_c20200317.csv.gz
# StormEvents_details-ftp_v1.0_d2013_c20170519.csv.gz
# StormEvents_details-ftp_v1.0_d2014_c20191116.csv.gz
# StormEvents_details-ftp_v1.0_d2015_c20191116.csv.gz
# StormEvents_details-ftp_v1.0_d2016_c20190817.csv.gz
# StormEvents_details-ftp_v1.0_d2017_c20200616.csv.gz
# StormEvents_details-ftp_v1.0_d2018_c20200819.csv.gz
# StormEvents_details-ftp_v1.0_d2019_c20201017.csv.gz
# StormEvents_details-ftp_v1.0_d2020_c20201017.csv.gz

# %% [markdown]
# # Downloaded gz files and unzip them into .csv files

# %%
import wget
import gzip

download_directory = "../raw data/Storms/temp/"
csv_files = []

for gz_file in gz_files:
    url = "https://www1.ncdc.noaa.gov/pub/data/swdi/stormevents/csvfiles/" + gz_file
    download = wget.download(url, out=download_directory)
    print(download)
    
    in_file = "../raw data/Storms/temp/" + gz_file
    input = gzip.GzipFile(in_file, 'rb')
    s = input.read()
    input.close()
    print()

    filename = gz_file[:-3]
    print(filename)
        
    out_file = "../raw data/Storms/" + filename
    output = open(out_file, 'wb')
    output.write(s)
    output.close()
    
    csv_files.append(out_file)
    break
# Out:
# ../raw data/Storms/temp//StormEvents_details-ftp_v1.0_d1950_c20170120.csv (1).gz
#
# StormEvents_details-ftp_v1.0_d1950_c20170120.csv

# %%
csv_files = []

for gz_file in gz_files:
    filename = gz_file[:-3]
    out_file = "../raw data/Storms/" + filename
    csv_files.append(out_file)

for file in csv_files:  
    print(file)
# Out:
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1950_c20170120.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1951_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1952_c20170619.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1953_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1954_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1955_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1956_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1957_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1958_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1959_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1960_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1961_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1962_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1963_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1964_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1965_c20190920.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1966_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1967_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1968_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1969_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1970_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1971_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1972_c20181029.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1973_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1974_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1975_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1976_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1977_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1978_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1979_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1980_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1981_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1982_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1983_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1984_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1985_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1986_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1987_c20160223.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1988_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1989_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1990_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1991_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1992_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1993_c20190920.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1994_c20190920.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1995_c20190920.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1996_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1997_c20190920.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1998_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1999_c20200518.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2000_c20200707.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2001_c20200518.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2002_c20200518.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2003_c20200518.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2004_c20200518.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2005_c20200518.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2006_c20200518.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2007_c20170717.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2008_c20180718.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2009_c20180718.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2010_c20200922.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2011_c20180718.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2012_c20200317.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2013_c20170519.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2014_c20191116.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2015_c20191116.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2016_c20190817.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2017_c20200616.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2018_c20200819.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2019_c20201017.csv
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2020_c20201017.csv

# %% [markdown]
# # Create database storms_db

# %%
from config import username, password
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
from getpass import getpass

url = f'postgresql://{username}:{password}@localhost:5432/storms_db'

# Create an engine object.
engine = create_engine(url, echo=True)

# Create database if it does not exist.
if not database_exists(engine.url):
    create_database(engine.url)
    connection = engine.connect()
else:
    # Connect the database if exists.
    connection = engine.connect()
# Out:
# 2020-11-04 21:34:20,914 INFO sqlalchemy.engine.base.Engine select version()
# 2020-11-04 21:34:20,915 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:34:20,916 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2020-11-04 21:34:20,917 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:34:20,919 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-11-04 21:34:20,920 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:34:20,921 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-11-04 21:34:20,922 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:34:20,923 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2020-11-04 21:34:20,923 INFO sqlalchemy.engine.base.Engine {}

# %% [markdown]
# # Create table storms

# %%
# Create table if it does not exist.
engine.execute('CREATE TABLE IF NOT EXISTS "storms" ('
'index BIGINT,'
'state TEXT,'
'event_type TEXT,' 
'begin_date_time TEXT,'
'magnitude BIGINT,'
'category FLOAT(53),' 
'tor_f_scale TEXT,'
'date DATE,'
'year INT);')
# Out:
# 2020-11-04 21:34:20,937 INFO sqlalchemy.engine.base.Engine CREATE TABLE IF NOT EXISTS "storms" (index BIGINT,state TEXT,event_type TEXT,begin_date_time TEXT,magnitude BIGINT,category FLOAT(53),tor_f_scale TEXT,date DATE,year INT);
# 2020-11-04 21:34:20,938 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:34:20,950 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# # Load csv files into table

# %%
for file in csv_files:
    print(file)
    csv_df = pd.read_csv(file)
    
    storms_df = csv_df.loc[:,["STATE","EVENT_TYPE","BEGIN_DATE_TIME","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
    
    storms_df = storms_df.rename(columns={'STATE':'state','EVENT_TYPE':'event_type','BEGIN_DATE_TIME':'begin_date_time'})
    storms_df = storms_df.rename(columns={'MAGNITUDE':'magnitude','CATEGORY':'category','TOR_F_SCALE':'tor_f_scale'})

    storms_df['begin_date_time'] = storms_df['begin_date_time'].str.split(' ').str[0]
    
    df = pd.DataFrame()
    yyyy = []
    
    df["dd"] = storms_df['begin_date_time'].str.split('-').str[0]
    df["mmm"] = storms_df['begin_date_time'].str.split('-').str[1]
    df["yy"] = storms_df['begin_date_time'].str.split('-').str[2]
    
    for row in df["yy"]:
       yy = int(row) 
       if (yy  < 50):
           yy += 2000
           yyyy.append(yy)
       else:
           yy += 1900
           yyyy.append(yy)
    
    storms_df["date"] = pd.to_datetime(
    str(yyyy[0]) + "-" + df["mmm"].astype(str) + "-" + df["dd"].astype(str))   

    storms_df["year"] = int(yyyy[0])
    
    storms_df.dropna() 
    storms_df.fillna(0)
  
    storms_df.to_sql('storms', connection, if_exists='append')
      
storms_df.head(2)
# Out:
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1950_c20170120.csv
# 2020-11-04 21:34:21,045 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:34:21,046 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:34:21,050 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:34:21,055 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:34:21,056 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '28-APR-50', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F3', 'date': datetime.datetime(
52', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1952, 4, 5, 0, 0), 'year': 1952}, {'index': 6, 'state': 'PENNSYLVANIA', 'event_type': 'Tornado', 'begin_date_time': '19-JUL-52', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1952, 7, 19, 0, 0), 'year': 1952}, {'index': 7, 'state': 'PENNSYLVANIA', 'event_type': 'Tornado', 'begin_date_time': '23-JUL-52', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1952, 7, 23, 0, 0), 'year': 1952}  ... displaying 10 of 272 total bound parameter sets ...  {'index': 270, 'state': 'TENNESSEE', 'event_type': 'Tornado', 'begin_date_time': '22-MAR-52', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1952, 3, 22, 0, 0), 'year': 1952}, {'index': 271, 'state': 'TENNESSEE', 'event_type': 'Tornado', 'begin_date_time': '30-JUN-52', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1952, 6, 30, 0, 0), 'year': 1952})
# 2020-11-04 21:34:21,300 INFO sqlalchemy.engine.base.Engine COMMIT
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1953_c20160223.csv
# 2020-11-04 21:34:21,339 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:34:21,340 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:34:21,342 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:34:21,347 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:34:21,348 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'FLORIDA', 'event_type': 'Tornado', 'begin_date_time': '13-DEC-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1953, 12, 13, 0, 0), 'year': 1953}, {'index': 1, 'state': 'WYOMING', 'event_type': 'Tornado', 'begin_date_time': '29-MAY-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1953, 5, 29, 0, 0), 'year': 1953}, {'index': 2, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '29-MAR-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1953, 3, 29, 0, 0), 'year': 1953}, {'index': 3, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '02-APR-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F0', 'date': datetime.datetime(1953, 4, 2, 0, 0), 'year': 1953}, {'index': 4, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '14-APR-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1953, 4, 14, 0, 0), 'year': 1953}, {'index': 5, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '14-APR-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1953, 4, 14, 0, 0), 'year': 1953}, {'index': 6, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '23-APR-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1953, 4, 23, 0, 0), 'year': 1953}, {'index': 7, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '23-APR-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1953, 4, 23, 0, 0), 'year': 1953}  ... displaying 10 of 492 total bound parameter sets ...  {'index': 490, 'state': 'TENNESSEE', 'event_type': 'Tornado', 'begin_date_time': '14-MAY-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1953, 5, 14, 0, 0), 'year': 1953}, {'index': 491, 'state': 'TENNESSEE', 'event_type': 'Tornado', 'begin_date_time': '20-JAN-53', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1953, 1, 20, 0, 0), 'year': 1953})
# 2020-11-04 21:34:21,419 INFO sqlalchemy.engine.base.Engine COMMIT
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1954_c20160223.csv
# 2020-11-04 21:34:21,464 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:34:21,465 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:34:21,468 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:34:21,473 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:34:21,473 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '24-MAR-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1954, 3, 24, 0, 0), 'year': 1954}, {'index': 1, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '27-APR-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F0', 'date': datetime.datetime(1954, 4, 27, 0, 0), 'year': 1954}, {'index': 2, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '01-MAY-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F3', 'date': datetime.datetime(1954, 5, 1, 0, 0), 'year': 1954}, {'index': 3, 'state': 'OHIO', 'event_type': 'Tornado', 'begin_date_time': '30-AUG-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1954, 8, 30, 0, 0), 'year': 1954}, {'index': 4, 'state': 'OHIO', 'event_type': 'Tornado', 'begin_date_time': '30-SEP-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1954, 9, 30, 0, 0), 'year': 1954}, {'index': 5, 'state': 'OHIO', 'event_type': 'Tornado', 'begin_date_time': '11-OCT-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1954, 10, 11, 0, 0), 'year': 1954}, {'index': 6, 'state': 'MISSISSIPPI', 'event_type': 'Tornado', 'begin_date_time': '20-FEB-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1954, 2, 20, 0, 0), 'year': 1954}, {'index': 7, 'state': 'MISSISSIPPI', 'event_type': 'Tornado', 'begin_date_time': '28-APR-54', 'magnitude': 0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1954, 4, 28, 0, 0), 'year': 1954}  ... displaying 10 of 609 total bound parameter sets ...  {'index': 607, 'state': 'TENNESSEE', 'event_type': 'Tornado', 'begin_date_time': '03-MAY-54', 'magnitude': 0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(
0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1958, 7, 31, 0, 0), 'year': 1958}  ... displaying 10 of 2213 total bound parameter sets ...  {'index': 2211, 'state': 'COLORADO', 'event_type': 'Hail', 'begin_date_time': '15-JUL-58', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1958, 7, 15, 0, 0), 'year': 1958}, {'index': 2212, 'state': 'COLORADO', 'event_type': 'Hail', 'begin_date_time': '15-JUL-58', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1958, 7, 15, 0, 0), 'year': 1958})
# 2020-11-04 21:34:22,825 INFO sqlalchemy.engine.base.Engine COMMIT
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1959_c20160223.csv
# 2020-11-04 21:34:22,885 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:34:22,886 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:34:22,889 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:34:22,900 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:34:22,901 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'MICHIGAN', 'event_type': 'Tornado', 'begin_date_time': '08-OCT-59', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1959, 10, 8, 0, 0), 'year': 1959}, {'index': 1, 'state': 'MISSOURI', 'event_type': 'Hail', 'begin_date_time': '19-APR-59', 'magnitude': 1.75, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1959, 4, 19, 0, 0), 'year': 1959}, {'index': 2, 'state': 'IOWA', 'event_type': 'Tornado', 'begin_date_time': '09-MAY-59', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1959, 5, 9, 0, 0), 'year': 1959}, {'index': 3, 'state': 'TEXAS', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '04-MAY-59', 'magnitude': 60.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1959, 5, 4, 0, 0), 'year': 1959}, {'index': 4, 'state': 'TENNESSEE', 'event_type': 'Hail', 'begin_date_time': '20-APR-59', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1959, 4, 20, 0, 0), 'year': 1959}, {'index': 5, 'state': 'NEW MEXICO', 'event_type': 'Tornado', 'begin_date_time': '08-MAY-59', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1959, 5, 8, 0, 0), 'year': 1959}, {'index': 6, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '09-MAY-59', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F3', 'date': datetime.datetime(1959, 5, 9, 0, 0), 'year': 1959}, {'index': 7, 'state': 'TEXAS', 'event_type': 'Hail', 'begin_date_time': '24-SEP-59', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1959, 9, 24, 0, 0), 'year': 1959}  ... displaying 10 of 1813 total bound parameter sets ...  {'index': 1811, 'state': 'KENTUCKY', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '10-FEB-59', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1959, 2, 10, 0, 0), 'year': 1959}, {'index': 1812, 'state': 'ARKANSAS', 'event_type': 'Hail', 'begin_date_time': '11-JUL-59', 'magnitude': 1.75, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1959, 7, 11, 0, 0), 'year': 1959})
# 2020-11-04 21:34:23,095 INFO sqlalchemy.engine.base.Engine COMMIT
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1960_c20160223.csv
# 2020-11-04 21:34:23,148 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:34:23,148 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:34:23,152 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:34:23,164 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:34:23,165 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'NEBRASKA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '11-JUL-60', 'magnitude': 91.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1960, 7, 11, 0, 0), 'year': 1960}, {'index': 1, 'state': 'NEBRASKA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '15-JUN-60', 'magnitude': 85.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1960, 6, 15, 0, 0), 'year': 1960}, {'index': 2, 'state': 'MONTANA', 'event_type': 'Tornado', 'begin_date_time': '22-JUL-60', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F0', 'date': datetime.datetime(1960, 7, 22, 0, 0), 'year': 1960}, {'index': 3, 'state': 'IOWA', 'event_type': 'Hail', 'begin_date_time': '29-MAR-60', 'magnitude': 1.5, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1960, 3, 29, 0, 0), 'year': 1960}, {'index': 4, 'state': 'OKLAHOMA', 'event_type': 'Tornado', 'begin_date_time': '05-MAY-60', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F3', 'date': datetime.datetime(1960, 5, 5, 0, 0), 'year': 1960}, {'index': 5, 'state': 'SOUTH CAROLINA', 'event_type': 'Tornado', 'begin_date_time': '30-MAR-60', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1960, 3, 30, 0, 0), 'year': 1960}, {'index': 6, 'state': 'TEXAS', 'event_type': 'Tornado', 'begin_date_time': '17-MAY-60', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F0', 'date': datetime.datetime(
 'state': 'ALABAMA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '17-JUL-62', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1962, 7, 17, 0, 0), 'year': 1962}  ... displaying 10 of 2389 total bound parameter sets ...  {'index': 2387, 'state': 'IOWA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '07-MAY-62', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1962, 5, 7, 0, 0), 'year': 1962}, {'index': 2388, 'state': 'COLORADO', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '12-MAY-62', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1962, 5, 12, 0, 0), 'year': 1962})
# 2020-11-04 21:34:24,054 INFO sqlalchemy.engine.base.Engine COMMIT
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1963_c20160223.csv
# 2020-11-04 21:34:24,111 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:34:24,112 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:34:24,115 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:34:24,128 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:34:24,129 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'MINNESOTA', 'event_type': 'Hail', 'begin_date_time': '07-AUG-63', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1963, 8, 7, 0, 0), 'year': 1963}, {'index': 1, 'state': 'NEW JERSEY', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '08-DEC-63', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1963, 12, 8, 0, 0), 'year': 1963}, {'index': 2, 'state': 'ALABAMA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '11-JAN-63', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1963, 1, 11, 0, 0), 'year': 1963}, {'index': 3, 'state': 'ALABAMA', 'event_type': 'Tornado', 'begin_date_time': '19-JAN-63', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F2', 'date': datetime.datetime(1963, 1, 19, 0, 0), 'year': 1963}, {'index': 4, 'state': 'ALABAMA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '20-JAN-63', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1963, 1, 20, 0, 0), 'year': 1963}, {'index': 5, 'state': 'ALABAMA', 'event_type': 'Tornado', 'begin_date_time': '05-MAR-63', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F4', 'date': datetime.datetime(1963, 3, 5, 0, 0), 'year': 1963}, {'index': 6, 'state': 'ALABAMA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '05-MAR-63', 'magnitude': 0.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1963, 3, 5, 0, 0), 'year': 1963}, {'index': 7, 'state': 'ALABAMA', 'event_type': 'Tornado', 'begin_date_time': '05-MAR-63', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1963, 3, 5, 0, 0), 'year': 1963}  ... displaying 10 of 1968 total bound parameter sets ...  {'index': 1966, 'state': 'WASHINGTON', 'event_type': 'Hail', 'begin_date_time': '13-AUG-63', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1963, 8, 13, 0, 0), 'year': 1963}, {'index': 1967, 'state': 'FLORIDA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '19-FEB-63', 'magnitude': 52.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1963, 2, 19, 0, 0), 'year': 1963})
# 2020-11-04 21:34:24,339 INFO sqlalchemy.engine.base.Engine COMMIT
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d1964_c20160223.csv
# 2020-11-04 21:34:24,395 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:34:24,396 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:34:24,400 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:34:24,416 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:34:24,416 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'ARKANSAS', 'event_type': 'Tornado', 'begin_date_time': '04-MAR-64', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F3', 'date': datetime.datetime(1964, 3, 4, 0, 0), 'year': 1964}, {'index': 1, 'state': 'NEBRASKA', 'event_type': 'Tornado', 'begin_date_time': '05-MAY-64', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F4', 'date': datetime.datetime(1964, 5, 5, 0, 0), 'year': 1964}, {'index': 2, 'state': 'NEW JERSEY', 'event_type': 'Tornado', 'begin_date_time': '10-MAR-64', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1964, 3, 10, 0, 0), 'year': 1964}, {'index': 3, 'state': 'NEW JERSEY', 'event_type': 'Tornado', 'begin_date_time': '10-MAR-64', 'magnitude': 0.0, 'category': None, 'tor_f_scale': 'F1', 'date': datetime.datetime(1964, 3, 10, 0, 0), 'year': 1964}, {'index': 4, 'state': 'NEBRASKA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '07-JUL-64', 'magnitude': 82.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1964, 7, 7, 0, 0), 'year': 1964}, {'index': 5, 'state': 'MINNESOTA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '08-MAY-64', 'magnitude': 50.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(1964, 5, 8, 0, 0), 'year': 1964}, {'index': 6, 'state': 'NEBRASKA', 'event_type': 'Hail', 'begin_date_time': '23-MAY-64', 'magnitude': 2.75, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(
', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '20-OCT-19', 'magnitude': 56.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2019, 10, 20, 0, 0), 'year': 2019}, {'index': 4, 'state': 'TEXAS', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '20-OCT-19', 'magnitude': 65.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2019, 10, 20, 0, 0), 'year': 2019}, {'index': 5, 'state': 'TEXAS', 'event_type': 'Tornado', 'begin_date_time': '20-OCT-19', 'magnitude': None, 'category': None, 'tor_f_scale': 'EF1', 'date': datetime.datetime(2019, 10, 20, 0, 0), 'year': 2019}, {'index': 6, 'state': 'VERMONT', 'event_type': 'Hail', 'begin_date_time': '04-SEP-19', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2019, 9, 4, 0, 0), 'year': 2019}, {'index': 7, 'state': 'NEW YORK', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '26-SEP-19', 'magnitude': 50.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2019, 9, 26, 0, 0), 'year': 2019}  ... displaying 10 of 67563 total bound parameter sets ...  {'index': 67561, 'state': 'TEXAS', 'event_type': 'Hail', 'begin_date_time': '08-AUG-19', 'magnitude': 1.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2019, 8, 8, 0, 0), 'year': 2019}, {'index': 67562, 'state': 'MISSOURI', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '18-MAY-19', 'magnitude': 61.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2019, 5, 18, 0, 0), 'year': 2019})
# 2020-11-04 21:37:39,363 INFO sqlalchemy.engine.base.Engine COMMIT
# ../raw data/Storms/StormEvents_details-ftp_v1.0_d2020_c20201017.csv
# 2020-11-04 21:37:40,202 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:40,203 INFO sqlalchemy.engine.base.Engine {'name': 'storms'}
# 2020-11-04 21:37:40,222 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-04 21:37:40,530 INFO sqlalchemy.engine.base.Engine INSERT INTO storms (index, state, event_type, begin_date_time, magnitude, category, tor_f_scale, date, year) VALUES (%(index)s, %(state)s, %(event_type)s, %(begin_date_time)s, %(magnitude)s, %(category)s, %(tor_f_scale)s, %(date)s, %(year)s)
# 2020-11-04 21:37:40,531 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'state': 'GEORGIA', 'event_type': 'Thunderstorm Wind', 'begin_date_time': '24-JUN-20', 'magnitude': 50.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 6, 24, 0, 0), 'year': 2020}, {'index': 1, 'state': 'WEST VIRGINIA', 'event_type': 'Flash Flood', 'begin_date_time': '25-MAY-20', 'magnitude': None, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 5, 25, 0, 0), 'year': 2020}, {'index': 2, 'state': 'ALABAMA', 'event_type': 'Hail', 'begin_date_time': '22-MAY-20', 'magnitude': 1.75, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 5, 22, 0, 0), 'year': 2020}, {'index': 3, 'state': 'ALABAMA', 'event_type': 'Hail', 'begin_date_time': '22-MAY-20', 'magnitude': 1.75, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 5, 22, 0, 0), 'year': 2020}, {'index': 4, 'state': 'WEST VIRGINIA', 'event_type': 'Strong Wind', 'begin_date_time': '10-APR-20', 'magnitude': 31.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 4, 10, 0, 0), 'year': 2020}, {'index': 5, 'state': 'VIRGINIA', 'event_type': 'Flood', 'begin_date_time': '13-APR-20', 'magnitude': None, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 4, 13, 0, 0), 'year': 2020}, {'index': 6, 'state': 'VIRGINIA', 'event_type': 'Strong Wind', 'begin_date_time': '12-APR-20', 'magnitude': 42.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 4, 12, 0, 0), 'year': 2020}, {'index': 7, 'state': 'CALIFORNIA', 'event_type': 'High Wind', 'begin_date_time': '29-JAN-20', 'magnitude': 56.0, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 1, 29, 0, 0), 'year': 2020}  ... displaying 10 of 40037 total bound parameter sets ...  {'index': 40035, 'state': 'IOWA', 'event_type': 'Flood', 'begin_date_time': '23-JUN-20', 'magnitude': None, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 6, 23, 0, 0), 'year': 2020}, {'index': 40036, 'state': 'IOWA', 'event_type': 'Flood', 'begin_date_time': '23-JUN-20', 'magnitude': None, 'category': None, 'tor_f_scale': None, 'date': datetime.datetime(2020, 6, 23, 0, 0), 'year': 2020})
# 2020-11-04 21:37:44,401 INFO sqlalchemy.engine.base.Engine COMMIT
#            state         event_type begin_date_time  magnitude  category  \
# 0        GEORGIA  Thunderstorm Wind       24-JUN-20       50.0       NaN
# 1  WEST VIRGINIA        Flash Flood       25-MAY-20        NaN       NaN
#
#   tor_f_scale       date  year
# 0         NaN 2020-06-24  2020
# 1         NaN 2020-05-25  2020

# %%
Tornadoes = "'TORNADO/WATERSPOUT','Waterspout','TORNADOES','TSTM WIND, HAIL','Dust Devil','Tornado','Funnel Cloud'"

Floods = "'Lakeshore Flood','Coastal Flood','Debris Flow','Flood','Flash Flood','THUNDERSTORM WINDS/FLASH FLOOD',\
'THUNDERSTORM WINDS/FLOODING','Heavy Rain','Storm Surge/Tide','High Surf','Sneakerwave','Rip Current','Astronomical Low Tide','Sneakerwave',\
'Seiche'"

Hurricanes = "'Tropical Depression','Tropical Storm','Hurricane','Hurricane (Typhoon)','Marine Hurricane/Typhoon',\
'Marine Tropical Storm', 'Marine Tropical Depression'"

Winds = "'Marine High Wind','Marine Strong Wind','Strong Wind','High Wind','Heavy Wind','Wind'"

Cold = "'Sleet','Frost/Freeze','Lake-Effect Snow','Freezing Fog','Extreme Cold/Wind Chill','Avalanche','Blizzard',\
'Cold/Wind Chill','Heavy Snow','Ice Storm','Winter Storm','Winter Weather','High Snow'"

Thunderstorms = "'Lightning','Marine Lightning','Marine Thunderstorm Wind','THUNDERSTORM WIND/ TREE',\
'THUNDERSTORM WIND/ TREES','THUNDERSTORM WINDS FUNNEL CLOU','THUNDERSTORM WINDS HEAVY RAIN',\
'THUNDERSTORM WINDS LIGHTNING','THUNDERSTORM WINDS/ FLOOD','THUNDERSTORM WINDS/HEAVY RAIN','Thunderstorm Wind',\
'HAIL FLOODING','HAIL/ICY ROADS','Marine Hail'"

Heat = "'Excessive Heat'"

VolcanicAsh = "'Volcanic Ashfall'"

DenseFog = "'Marine Dense Fog'"

# %%
engine.execute('ALTER TABLE storms ADD COLUMN type varchar')
# Out:
# 2020-11-04 21:37:44,444 INFO sqlalchemy.engine.base.Engine ALTER TABLE storms ADD COLUMN type varchar
# 2020-11-04 21:37:44,444 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:44,453 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
engine.execute("UPDATE storms set type='Tornadoes' WHERE event_type in (" + Tornadoes + ")")

engine.execute("UPDATE storms set type='Floods' WHERE event_type in (" + Floods + ")")

engine.execute("UPDATE storms set type='Hurricanes' WHERE event_type in (" + Hurricanes + ")")

engine.execute("UPDATE storms set type='Winds' WHERE event_type in (" + Winds + ")")

engine.execute("UPDATE storms set type='Cold' WHERE event_type in (" + Cold + ")")

engine.execute("UPDATE storms set type='Thunderstorms' WHERE event_type in (" + Thunderstorms + ")")

engine.execute("UPDATE storms set type='Heat' WHERE event_type in (" + Heat + ")")
# Out:
# 2020-11-04 21:37:44,460 INFO sqlalchemy.engine.base.Engine UPDATE storms set type='Tornadoes' WHERE event_type in ('TORNADO/WATERSPOUT','Waterspout','TORNADOES','TSTM WIND, HAIL','Dust Devil','Tornado','Funnel Cloud')
# 2020-11-04 21:37:44,460 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:45,462 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-04 21:37:45,467 INFO sqlalchemy.engine.base.Engine UPDATE storms set type='Floods' WHERE event_type in ('Lakeshore Flood','Coastal Flood','Debris Flow','Flood','Flash Flood','THUNDERSTORM WINDS/FLASH FLOOD','THUNDERSTORM WINDS/FLOODING','Heavy Rain','Storm Surge/Tide','High Surf','Sneakerwave','Rip Current','Astronomical Low Tide','Sneakerwave','Seiche')
# 2020-11-04 21:37:45,468 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:47,284 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-04 21:37:47,289 INFO sqlalchemy.engine.base.Engine UPDATE storms set type='Hurricanes' WHERE event_type in ('Tropical Depression','Tropical Storm','Hurricane','Hurricane (Typhoon)','Marine Hurricane/Typhoon','Marine Tropical Storm', 'Marine Tropical Depression')
# 2020-11-04 21:37:47,290 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:48,086 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-04 21:37:48,088 INFO sqlalchemy.engine.base.Engine UPDATE storms set type='Winds' WHERE event_type in ('Marine High Wind','Marine Strong Wind','Strong Wind','High Wind','Heavy Wind','Wind')
# 2020-11-04 21:37:48,088 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:48,971 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-04 21:37:48,975 INFO sqlalchemy.engine.base.Engine UPDATE storms set type='Cold' WHERE event_type in ('Sleet','Frost/Freeze','Lake-Effect Snow','Freezing Fog','Extreme Cold/Wind Chill','Avalanche','Blizzard','Cold/Wind Chill','Heavy Snow','Ice Storm','Winter Storm','Winter Weather','High Snow')
# 2020-11-04 21:37:48,976 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:51,280 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-04 21:37:51,285 INFO sqlalchemy.engine.base.Engine UPDATE storms set type='Thunderstorms' WHERE event_type in ('Lightning','Marine Lightning','Marine Thunderstorm Wind','THUNDERSTORM WIND/ TREE','THUNDERSTORM WIND/ TREES','THUNDERSTORM WINDS FUNNEL CLOU','THUNDERSTORM WINDS HEAVY RAIN','THUNDERSTORM WINDS LIGHTNING','THUNDERSTORM WINDS/ FLOOD','THUNDERSTORM WINDS/HEAVY RAIN','Thunderstorm Wind','HAIL FLOODING','HAIL/ICY ROADS','Marine Hail')
# 2020-11-04 21:37:51,286 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:54,584 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-04 21:37:54,587 INFO sqlalchemy.engine.base.Engine UPDATE storms set type='Heat' WHERE event_type in ('Excessive Heat')
# 2020-11-04 21:37:54,588 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:55,204 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
type_df = pd.read_sql(
    "SELECT type, count(*) as frequency FROM storms WHERE date > '1995-12-31' and type !='None' group by type order by frequency desc",
    connection
)

type_df
# Out:
# 2020-11-04 21:37:55,215 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:55,216 INFO sqlalchemy.engine.base.Engine {'name': "SELECT type, count(*) as frequency FROM storms WHERE date > '1995-12-31' and type !='None' group by type order by frequency desc"}
# 2020-11-04 21:37:55,275 INFO sqlalchemy.engine.base.Engine SELECT type, count(*) as frequency FROM storms WHERE date > '1995-12-31' and type !='None' group by type order by frequency desc
# 2020-11-04 21:37:55,275 INFO sqlalchemy.engine.base.Engine {}
#             type  frequency
# 0  Thunderstorms     397072
# 1           Cold     270020
# 2         Floods     188539
# 3          Winds      95084
# 4      Tornadoes      48487
# 5           Heat       8812
# 6     Hurricanes       7792

# %%
event_df = pd.read_sql(
    "SELECT type FROM storms WHERE date > '1995-12-31' and type !='None'",
    connection
)

value_counts = event_df["type"].value_counts()

plt.bar(value_counts.index.values,value_counts.values)
plt.xlabel("Type of Event")
plt.xticks(rotation=90)
plt.ylabel("Frequency")
plt.show()
# Out:
# 2020-11-04 21:37:55,596 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:55,597 INFO sqlalchemy.engine.base.Engine {'name': "SELECT type FROM storms WHERE date > '1995-12-31' and type !='None'"}
# 2020-11-04 21:37:55,598 INFO sqlalchemy.engine.base.Engine SELECT type FROM storms WHERE date > '1995-12-31' and type !='None'
# 2020-11-04 21:37:55,598 INFO sqlalchemy.engine.base.Engine {}

# %%
thunderstorms_df = pd.read_sql("SELECT year, type, count(*) FROM storms WHERE type='Thunderstorms' \
                and date > '1995-12-31' group by year, type order by year",connection)

cold_df = pd.read_sql("SELECT year, type, count(*) FROM storms WHERE type='Cold' \
                and date > '1995-12-31' group by year, type order by year",connection)

floods_df = pd.read_sql("SELECT year, type, count(*) FROM storms WHERE type='Floods' \
                and date > '1995-12-31' group by year, type order by year",connection)

winds_df = pd.read_sql("SELECT year, type, count(*) FROM storms WHERE type='Winds' \
                and date > '1995-12-31' group by year, type order by year",connection)

tornadoes_df = pd.read_sql("SELECT year, type, count(*) FROM storms WHERE type='Tornadoes' \
                and date > '1995-12-31' group by year, type order by year", connection)

# heat_df = pd.read_sql("SELECT year, type, count(*) FROM storms WHERE type='Heat' \
#                 and date > '1995-12-31' group by year, type order by year", connection)

# hurricanes_df = pd.read_sql("SELECT year, type, count(*) FROM storms WHERE type='Hurricanes' \
#                 and date > '1995-12-31' group by year, type order by year", connection)
# Out:
# 2020-11-04 21:37:57,059 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:57,059 INFO sqlalchemy.engine.base.Engine {'name': "SELECT year, type, count(*) FROM storms WHERE type='Thunderstorms'                 and date > '1995-12-31' group by year, type order by year"}
# 2020-11-04 21:37:57,061 INFO sqlalchemy.engine.base.Engine SELECT year, type, count(*) FROM storms WHERE type='Thunderstorms'                 and date > '1995-12-31' group by year, type order by year
# 2020-11-04 21:37:57,061 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:57,265 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:57,266 INFO sqlalchemy.engine.base.Engine {'name': "SELECT year, type, count(*) FROM storms WHERE type='Cold'                 and date > '1995-12-31' group by year, type order by year"}
# 2020-11-04 21:37:57,268 INFO sqlalchemy.engine.base.Engine SELECT year, type, count(*) FROM storms WHERE type='Cold'                 and date > '1995-12-31' group by year, type order by year
# 2020-11-04 21:37:57,269 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:57,475 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:57,476 INFO sqlalchemy.engine.base.Engine {'name': "SELECT year, type, count(*) FROM storms WHERE type='Floods'                 and date > '1995-12-31' group by year, type order by year"}
# 2020-11-04 21:37:57,477 INFO sqlalchemy.engine.base.Engine SELECT year, type, count(*) FROM storms WHERE type='Floods'                 and date > '1995-12-31' group by year, type order by year
# 2020-11-04 21:37:57,478 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:57,657 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:57,658 INFO sqlalchemy.engine.base.Engine {'name': "SELECT year, type, count(*) FROM storms WHERE type='Winds'                 and date > '1995-12-31' group by year, type order by year"}
# 2020-11-04 21:37:57,659 INFO sqlalchemy.engine.base.Engine SELECT year, type, count(*) FROM storms WHERE type='Winds'                 and date > '1995-12-31' group by year, type order by year
# 2020-11-04 21:37:57,660 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 21:37:57,813 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-04 21:37:57,814 INFO sqlalchemy.engine.base.Engine {'name': "SELECT year, type, count(*) FROM storms WHERE type='Tornadoes'                 and date > '1995-12-31' group by year, type order by year"}
# 2020-11-04 21:37:57,815 INFO sqlalchemy.engine.base.Engine SELECT year, type, count(*) FROM storms WHERE type='Tornadoes'                 and date > '1995-12-31' group by year, type order by year
# 2020-11-04 21:37:57,816 INFO sqlalchemy.engine.base.Engine {}

# %%
thunderstorms_year_list = thunderstorms_df['year'].tolist()
thunderstorms_count_list = thunderstorms_df['count'].tolist()
Thunderstorms, = plt.plot(thunderstorms_year_list, thunderstorms_count_list, color="red", label="Thunderstorms" )

cold_year_list = cold_df['year'].tolist()
cold_count_list = cold_df['count'].tolist()
Cold, = plt.plot(cold_year_list, cold_count_list, color="black", label="Cold" )

floods_year_list = floods_df['year'].tolist()
floods_count_list = floods_df['count'].tolist()
Floods, = plt.plot(floods_year_list, floods_count_list, color="blue", label="Floods" )

winds_year_list = winds_df['year'].tolist()
winds_count_list = winds_df['count'].tolist()
Winds, = plt.plot(winds_year_list, winds_count_list, color="orange", label="Winds" )

tornadoes_year_list = tornadoes_df['year'].tolist()
tornadoes_count_list = tornadoes_df['count'].tolist()
Tornadoes, = plt.plot(tornadoes_year_list, tornadoes_count_list, color="green", label="Tornadoes" )

plt.legend(handles=[Thunderstorms,Cold,Floods,Tornadoes,Winds], loc="best")

# Show the chart
plt.show()

# %%
tornadoes_df = pd.read_sql(
    "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in\
    ('TORNADO/WATERSPOUT','Waterspout','TORNADOES','TSTM WIND, HAIL','Dust Devil','Tornado','Funnel Cloud')\
    and date > '01-Jan-1950' group by date order by date",
    connection
)

tornadoes_df
# Out:
# 2020-11-05 14:52:35,879 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-05 14:52:35,890 INFO sqlalchemy.engine.base.Engine {'name': "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('TORNADO/WATERSPOUT','Waterspout','TORNADOES','TSTM WIND, HAIL','Dust Devil','Tornado','Funnel Cloud')    and date > '01-Jan-1950' group by date order by date"}
# 2020-11-05 14:52:36,003 INFO sqlalchemy.engine.base.Engine SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('TORNADO/WATERSPOUT','Waterspout','TORNADOES','TSTM WIND, HAIL','Dust Devil','Tornado','Funnel Cloud')    and date > '01-Jan-1950' group by date order by date
# 2020-11-05 14:52:36,004 INFO sqlalchemy.engine.base.Engine {}
#              date  count
# 0      1950-01-03      4
# 1      1950-01-13      1
# 2      1950-01-25      2
# 3      1950-01-26      1
# 4      1950-02-11      4
# ...           ...    ...
# 13502  2020-07-25      9
# 13503  2020-07-26      7
# 13504  2020-07-27      1
# 13505  2020-07-29      5
# 13506  2020-07-31      5
#
# [13507 rows x 2 columns]

# %%
# Tornadoes Chart ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Tornadoes_Fig, Tornadoes = plt.subplots(figsize = (30,10), dpi = 200)
Tornadoes.set_title("Tornadoes Event 1950-2020")
Tornadoes.set_xlabel("Date")
Tornadoes.tick_params(axis="x", labelrotation=90)
Tornadoes.xaxis.set_major_locator(plt.MaxNLocator(20))
Tornadoes.set_ylabel("Number of Events")
Tornadoes_plot_df =  tornadoes_df.set_index("date")
Tornadoes.plot(Tornadoes_plot_df)
Tornadoes_Fig.savefig("../docs/assets/charts/storms/Tornadoes_Fig.png")

# %%
floods_df = pd.read_sql(
    "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in\
    ('Lakeshore Flood','Coastal Flood','Debris Flow','Flood','Flash Flood','THUNDERSTORM WINDS/FLASH FLOOD', \
'THUNDERSTORM WINDS/FLOODING','Heavy Rain','Storm Surge/Tide','High Surf','Sneakerwave','Rip Current','Astronomical Low Tide','Sneakerwave',\
'Seiche')\
    and date > '31-Dec-95' group by date order by date",
    connection
)

floods_df
# Out:
# 2020-11-05 15:07:19,924 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-05 15:07:19,926 INFO sqlalchemy.engine.base.Engine {'name': "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Lakeshore Flood','Coastal Flood','Debris Flow','Flood','Flash Flood','THUNDERSTORM WINDS/F ... (67 characters truncated) ... e/Tide','High Surf','Sneakerwave','Rip Current','Astronomical Low Tide','Sneakerwave','Seiche')    and date > '31-Dec-95' group by date order by date"}
# 2020-11-05 15:07:19,936 INFO sqlalchemy.engine.base.Engine SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Lakeshore Flood','Coastal Flood','Debris Flow','Flood','Flash Flood','THUNDERSTORM WINDS/FLASH FLOOD', 'THUNDERSTORM WINDS/FLOODING','Heavy Rain','Storm Surge/Tide','High Surf','Sneakerwave','Rip Current','Astronomical Low Tide','Sneakerwave','Seiche')    and date > '31-Dec-95' group by date order by date
# 2020-11-05 15:07:19,937 INFO sqlalchemy.engine.base.Engine {}
#             date  count
# 0     1996-01-01      1
# 1     1996-01-03      3
# 2     1996-01-07     15
# 3     1996-01-10      2
# 4     1996-01-11      1
# ...          ...    ...
# 8043  2020-07-27     36
# 8044  2020-07-28     17
# 8045  2020-07-29     37
# 8046  2020-07-30     72
# 8047  2020-07-31     29
#
# [8048 rows x 2 columns]

# %%
# Floods Chart ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Floods_Fig, Floods = plt.subplots(figsize = (30,10), dpi = 200)
Floods.set_title("Floods Event 1996-2020")
Floods.set_xlabel("Date")
Floods.tick_params(axis="x", labelrotation=90)
Floods.xaxis.set_major_locator(plt.MaxNLocator(20))
Floods.set_ylabel("Number of Events")
Floods_plot_df = floods_df.set_index("date")
Floods.plot(Floods_plot_df)
Floods_Fig.savefig("../docs/assets/charts/storms/Floods_Fig.png")

# %%
hurricanes_df = pd.read_sql(
    "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in\
    ('Tropical Depression','Tropical Storm','Hurricane','Hurricane (Typhoon)','Marine Hurricane/Typhoon',\
'Marine Tropical Storm', 'Marine Tropical Depression')\
    and date > '31-Dec-95' group by date order by date",
    connection
)

hurricanes_df
# Out:
# 2020-11-05 15:07:22,590 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-05 15:07:22,590 INFO sqlalchemy.engine.base.Engine {'name': "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Tropical Depression','Tropical Storm','Hurricane','Hurricane (Typhoon)','Marine Hurricane/Typhoon','Marine Tropical Storm', 'Marine Tropical Depression')    and date > '31-Dec-95' group by date order by date"}
# 2020-11-05 15:07:22,598 INFO sqlalchemy.engine.base.Engine SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Tropical Depression','Tropical Storm','Hurricane','Hurricane (Typhoon)','Marine Hurricane/Typhoon','Marine Tropical Storm', 'Marine Tropical Depression')    and date > '31-Dec-95' group by date order by date
# 2020-11-05 15:07:22,598 INFO sqlalchemy.engine.base.Engine {}
#            date  count
# 0    1996-06-18     38
# 1    1996-07-10      3
# 2    1996-07-11      9
# 3    1996-07-12     71
# 4    1996-07-13     17
# ..          ...    ...
# 399  2020-06-07      7
# 400  2020-07-10      9
# 401  2020-07-25     53
# 402  2020-07-29      6
# 403  2020-07-30      4
#
# [404 rows x 2 columns]

# %%
# Hurricanes Chart ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Hurricanes_Fig, Hurricanes = plt.subplots(figsize = (30,10), dpi = 200)
Hurricanes.set_title("Hurricanes Event 1996-2020")
Hurricanes.set_xlabel("Date")
Hurricanes.tick_params(axis="x", labelrotation=90)
Hurricanes.xaxis.set_major_locator(plt.MaxNLocator(20))
Hurricanes.set_ylabel("Number of Events")
Hurricanes_plot_df = hurricanes_df.set_index("date")
Hurricanes.plot(Hurricanes_plot_df)
Hurricanes_Fig.savefig("../docs/assets/charts/storms/Hurricanes_Fig.png")

# %%
winds_df = pd.read_sql(
    "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in\
    ('Marine High Wind','Marine Strong Wind','Strong Wind','High Wind','Heavy Wind','Wind')\
    and date > '31-Dec-95' group by date order by date",
    connection
)

winds_df
# Out:
# 2020-11-05 15:07:29,919 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-05 15:07:29,920 INFO sqlalchemy.engine.base.Engine {'name': "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Marine High Wind','Marine Strong Wind','Strong Wind','High Wind','Heavy Wind','Wind')    and date > '31-Dec-95' group by date order by date"}
# 2020-11-05 15:07:29,935 INFO sqlalchemy.engine.base.Engine SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Marine High Wind','Marine Strong Wind','Strong Wind','High Wind','Heavy Wind','Wind')    and date > '31-Dec-95' group by date order by date
# 2020-11-05 15:07:29,936 INFO sqlalchemy.engine.base.Engine {}
#             date  count
# 0     1996-01-01      6
# 1     1996-01-02      4
# 2     1996-01-03     17
# 3     1996-01-05      1
# 4     1996-01-06      7
# ...          ...    ...
# 5828  2020-07-11      1
# 5829  2020-07-13      2
# 5830  2020-07-14      2
# 5831  2020-07-20      1
# 5832  2020-07-29      1
#
# [5833 rows x 2 columns]

# %%
# Winds Chart ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Winds_Fig, Winds = plt.subplots(figsize = (30,10), dpi = 200)
Winds.set_title("Winds Event 1996-2020")
Winds.set_xlabel("Date")
Winds.tick_params(axis="x", labelrotation=90)
Winds.xaxis.set_major_locator(plt.MaxNLocator(20))
Winds.set_ylabel("Number of Events")
Winds_plot_df = winds_df.set_index("date")
Winds.plot(Winds_plot_df)
Winds_Fig.savefig("../docs/assets/charts/storms/Winds_Fig.png")

# %%
cold_df = pd.read_sql(
    "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in\
    ('Sleet','Frost/Freeze','Lake-Effect Snow','Freezing Fog','Extreme Cold/Wind Chill','Avalanche','Blizzard',\
'Cold/Wind Chill','Heavy Snow','Ice Storm','Winter Storm','Winter Weather','High Snow')\
    and date > '31-Dec-95' group by date order by date",
    connection
)

cold_df
# Out:
# 2020-11-05 15:07:33,266 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-05 15:07:33,268 INFO sqlalchemy.engine.base.Engine {'name': "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Sleet','Frost/Freeze','Lake-Effect Snow','Freezing Fog','Extreme Cold/Wind Chill','Avalanc ... (7 characters truncated) ... izzard','Cold/Wind Chill','Heavy Snow','Ice Storm','Winter Storm','Winter Weather','High Snow')    and date > '31-Dec-95' group by date order by date"}
# 2020-11-05 15:07:33,279 INFO sqlalchemy.engine.base.Engine SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Sleet','Frost/Freeze','Lake-Effect Snow','Freezing Fog','Extreme Cold/Wind Chill','Avalanche','Blizzard','Cold/Wind Chill','Heavy Snow','Ice Storm','Winter Storm','Winter Weather','High Snow')    and date > '31-Dec-95' group by date order by date
# 2020-11-05 15:07:33,280 INFO sqlalchemy.engine.base.Engine {}
#             date  count
# 0     1996-01-01    123
# 1     1996-01-02    323
# 2     1996-01-03     98
# 3     1996-01-04     52
# 4     1996-01-05     40
# ...          ...    ...
# 5225  2020-05-26      1
# 5226  2020-05-28      1
# 5227  2020-06-08     11
# 5228  2020-06-17      5
# 5229  2020-06-30      1
#
# [5230 rows x 2 columns]

# %%
# Cold Chart ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Cold_Fig, Cold = plt.subplots(figsize = (30,10), dpi = 200)
Cold.set_title("Cold Event 1996-2020")
Cold.set_xlabel("Date")
Cold.tick_params(axis="x", labelrotation=90)
Cold.xaxis.set_major_locator(plt.MaxNLocator(20))
Cold.set_ylabel("Number of Events")
Cold_plot_df = cold_df.set_index("date")
Cold.plot(Cold_plot_df)
Cold_Fig.savefig("../docs/assets/charts/storms/Cold_Fig.png")

# %%
thunderstorms_df = pd.read_sql(
    "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in\
    ('Lightning','Marine Lightning','Marine Thunderstorm Wind','THUNDERSTORM WIND/ TREE',\
'THUNDERSTORM WIND/ TREES','THUNDERSTORM WINDS FUNNEL CLOU','THUNDERSTORM WINDS HEAVY RAIN',\
'THUNDERSTORM WINDS LIGHTNING','THUNDERSTORM WINDS/ FLOOD','THUNDERSTORM WINDS/HEAVY RAIN','Thunderstorm Wind',\
'HAIL FLOODING','HAIL/ICY ROADS','Marine Hail')\
    and date > '01-Jan-1950' group by date order by date",
    connection
)

thunderstorms_df
# Out:
# 2020-11-05 15:07:37,532 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-05 15:07:37,533 INFO sqlalchemy.engine.base.Engine {'name': "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Lightning','Marine Lightning','Marine Thunderstorm Wind','THUNDERSTORM WIND/ TREE','THUNDE ... (150 characters truncated) ... ERSTORM WINDS/HEAVY RAIN','Thunderstorm Wind','HAIL FLOODING','HAIL/ICY ROADS','Marine Hail')    and date > '01-Jan-1950' group by date order by date"}
# 2020-11-05 15:07:37,536 INFO sqlalchemy.engine.base.Engine SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Lightning','Marine Lightning','Marine Thunderstorm Wind','THUNDERSTORM WIND/ TREE','THUNDERSTORM WIND/ TREES','THUNDERSTORM WINDS FUNNEL CLOU','THUNDERSTORM WINDS HEAVY RAIN','THUNDERSTORM WINDS LIGHTNING','THUNDERSTORM WINDS/ FLOOD','THUNDERSTORM WINDS/HEAVY RAIN','Thunderstorm Wind','HAIL FLOODING','HAIL/ICY ROADS','Marine Hail')    and date > '01-Jan-1950' group by date order by date
# 2020-11-05 15:07:37,537 INFO sqlalchemy.engine.base.Engine {}
#              date  count
# 0      1955-02-01      1
# 1      1955-02-05      1
# 2      1955-02-11      1
# 3      1955-03-01      5
# 4      1955-03-03      1
# ...           ...    ...
# 14952  2020-07-27     86
# 14953  2020-07-28    111
# 14954  2020-07-29     69
# 14955  2020-07-30    145
# 14956  2020-07-31    126
#
# [14957 rows x 2 columns]

# %%
# Thunderstorms Chart ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Thunderstorms_Fig, Thunderstorms = plt.subplots(figsize = (30,10), dpi = 200)
Thunderstorms.set_title("Thunderstorms Event 1950-2020")
Thunderstorms.set_xlabel("Date")
Thunderstorms.tick_params(axis="x", labelrotation=90)
Thunderstorms.xaxis.set_major_locator(plt.MaxNLocator(20))
Thunderstorms.set_ylabel("Number of Events")
Thunderstorms_plot_df = thunderstorms_df.set_index("date")
Thunderstorms.plot(Thunderstorms_plot_df)
Thunderstorms_Fig.savefig("../docs/assets/charts/storms/Thunderstorms_Fig.png")

# %%
heat_df = pd.read_sql(
    "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in\
    ('Excessive Heat')\
    and date > '31-Dec-95' group by date order by date",
    connection
)

heat_df
# Out:
# 2020-11-05 15:07:41,881 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-05 15:07:41,883 INFO sqlalchemy.engine.base.Engine {'name': "SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Excessive Heat')    and date > '31-Dec-95' group by date order by date"}
# 2020-11-05 15:07:41,885 INFO sqlalchemy.engine.base.Engine SELECT date, count(*) FROM storms WHERE EVENT_TYPE in    ('Excessive Heat')    and date > '31-Dec-95' group by date order by date
# 2020-11-05 15:07:41,886 INFO sqlalchemy.engine.base.Engine {}
#            date  count
# 0    2000-01-02     97
# 1    2000-02-23      4
# 2    2000-02-25     50
# 3    2000-02-26     50
# 4    2000-02-29      3
# ..          ...    ...
# 455  2020-07-17      1
# 456  2020-07-20      2
# 457  2020-07-24     16
# 458  2020-07-29      7
# 459  2020-07-30     18
#
# [460 rows x 2 columns]

# %%
# Heat Chart ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
Heat_Fig, Heat = plt.subplots(figsize = (30,10), dpi = 200)
Heat.set_title("Heat Event 1999-2020")
Heat.set_xlabel("Date")
Heat.tick_params(axis="x", labelrotation=90)
Heat.xaxis.set_major_locator(plt.MaxNLocator(20))
Heat.set_ylabel("Number of Events")
heat_plot_df = heat_df.set_index("date")
Heat.plot(heat_plot_df)
Heat_Fig.savefig("../docs/assets/charts/storms/Heat_Fig.png")
